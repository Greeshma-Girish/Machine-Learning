# %% [markdown]
# # Diabates Prediction - Neural Network(MLP)
# <h4><ul>
#     <li>Glucose: Plasma glucose yes/no</li>
#     <li>BloodPressure: Diastolic blood pressure (mm Hg) </li>
#     <li>Heart_disease: Yes or no</li>
#     <li>BMI: Body mass index (weight in kg/(height in m)^2)</li>
#     <li>Age: Age (years)</li>
#     <li>Gender : Male or Female</li>
#     <li>Outcome: Class variable (0 or 1)</li>
# </ul></h4>

# %% [markdown]
# # 1) Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import confusion_matrix,classification_report,roc_curve, auc,accuracy_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # 2) Initial Inspection

# %%
df=pd.read_csv(r'C:\Users\HP\diabetes.csv')
print(df.head())
print(df.tail())
print(df.info())
print(df.describe())
print(df.nunique())
# Out:
#    slno  gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0     1  Female  80.0           0.0            1.0           never  25.19
# 1     2  Female  54.0           0.0            0.0         No Info  27.32
# 2     3    Male  28.0           0.0            0.0           never  27.32
# 3     4  Female  36.0           0.0            0.0         current  23.45
# 4     5    Male  76.0           1.0            1.0         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes  height  weight
# 0          6.6                  140         0  171.52   74.11
# 1          6.6                   80         0  176.48   83.74
# 2          5.7                  158         0  163.29   58.46
# 3          5.0                  155         0  187.04   52.77
# 4          4.8                  155         0  154.72   68.39
#      slno  gender   age  hypertension  heart_disease smoking_history    bmi  \
# 695   696  Female  62.0           0.0            0.0            ever  27.27
# 696   697  Female  53.0           0.0            0.0            ever  42.40
# 697   698  Female  55.0           0.0            0.0           never  35.42
# 698   699  Female  64.0           0.0            0.0            ever  49.27
# 699   700  Female  40.0           0.0            0.0           never  31.16
#
#      HbA1c_level  blood_glucose_level  diabetes  height  weight
# 695          5.8                  130         0  160.22   64.78
# 696          6.1                  145         0  174.95   58.62
# 697          6.5                  140         0  177.31   67.39
# 698          8.2                  140         1  168.39   80.27
# 699          6.6                  159         1  182.65   79.69
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   slno                 700 non-null    int64
#  1   gender               697 non-null    object
#  2   age                  695 non-null    float64
#  3   hypertension         698 non-null    float64
#  4   heart_disease        699 non-null    float64
#  5   smoking_history      695 non-null    object
#  6   bmi                  697 non-null    float64
#  7   HbA1c_level          698 non-null    float64
#  8   blood_glucose_level  700 non-null    int64
#  9   diabetes             700 non-null    int64
#  10  height               700 non-null    float64
#  11  weight               700 non-null    float64
# dtypes: float64(7), int64(3), object(2)
# memory usage: 65.8+ KB
# None
#             slno         age  hypertension  heart_disease         bmi  \
# count  700.00000  695.000000    698.000000     699.000000  697.000000
# mean   350.50000   41.233957      0.063037       0.031474   27.074132
# std    202.21688   23.021994      0.243204       0.174719    7.093062
# min      1.00000    0.080000      0.000000       0.000000   10.300000
# 25%    175.75000   22.000000      0.000000       0.000000   22.830000
# 50%    350.50000   42.000000      0.000000       0.000000   27.320000
# 75%    525.25000   59.000000      0.000000       0.000000   29.300000
# max    700.00000   80.000000      1.000000       1.000000   69.370000
#
#        HbA1c_level  blood_glucose_level    diabetes      height      weight
# count   698.000000            700.00000  700.000000  700.000000  700.000000
# mean      5.612178            139.70000    0.092857  171.083000   70.797600
# std       1.110008             37.87214    0.290440    8.809857   11.041361
# min       3.500000             80.00000    0.000000  151.890000   44.300000
# 25%       4.800000            126.00000    0.000000  163.247500   62.032500
# 50%       5.800000            145.00000    0.000000  170.870000   70.115000
# 75%       6.200000            159.00000    0.000000  178.515000   79.337500
# max       9.000000            300.00000    1.000000  188.060000   96.620000
# slno                   700
# gender                   2
# age                     89
# hypertension             2
# heart_disease            2
# smoking_history          6
# bmi                    484
# HbA1c_level             18
# blood_glucose_level     17
# diabetes                 2
# height                 100
# weight                  99
# dtype: int64

# %% [markdown]
# # 3) Handle Missing Values

# %%
print(df.isnull().sum())
print(df.isnull().mean()*100)
for col in df.columns :
    if(df[col].dtype=="object"):
        df[col].fillna(df[col].mode()[0],inplace=True)
    else : 
        df[col].fillna(df[col].median(),inplace=True)
print(df.isnull().sum())

# Interpretation:
# - Ensure that no missing values remain after the imputation process.
# - Helps to confirm that the missing values were handled properly
# Out:
# slno                   0
# gender                 3
# age                    5
# hypertension           2
# heart_disease          1
# smoking_history        5
# bmi                    3
# HbA1c_level            2
# blood_glucose_level    0
# diabetes               0
# height                 0
# weight                 0
# dtype: int64
# slno                   0.000000
# gender                 0.428571
# age                    0.714286
# hypertension           0.285714
# heart_disease          0.142857
# smoking_history        0.714286
# bmi                    0.428571
# HbA1c_level            0.285714
# blood_glucose_level    0.000000
# diabetes               0.000000
# height                 0.000000
# weight                 0.000000
# dtype: float64
# slno                   0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# height                 0
# weight                 0
# dtype: int64

# %% [markdown]
# <h3>Interpretation : </h3>
# <span style="font-style: italic; font-size: 18px;">Handled missing values by imputing mean for numnericals and mode for categories,Ensure that no missing values remain after the imputation process.
# Helps to confirm that the missing values were handled properly </span>

# %% [markdown]
# # 4) Drop Columns

# %%
# Remove the column 'sl.no',weight,height'
df.drop(columns=['slno'], inplace=True)
print("\nColumns after removing 'sl.no':")
print(df.columns)
# Out:
# Columns after removing 'sl.no':
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history',
#        'bmi', 'HbA1c_level', 'blood_glucose_level', 'diabetes', 'height',
#        'weight'],
#       dtype='object')

# %% [markdown]
# <h3>Interpretation : </h3>
# <span style="font-style: italic;font-size: 18px;">Dropped unwanted column from the dataset ie slno in the dataset.</span>

# %% [markdown]
# # 5) Univariate Analysis - Histogram

# %%
# Univariate Analysis : Plot histograms and check skewness for all numerical columns
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
rows = (len(numerical_columns) // 3) + (1 if len(numerical_columns) % 3 != 0 else 0)
cols = min(len(numerical_columns), 3)

plt.figure(figsize=(15, rows * 5))
for i, col in enumerate(numerical_columns, 1):
    # Mean, Median, and Skewness Calculation
    mean = df[col].mean()
    median = df[col].median()
    skewness = df[col].skew()

    # Determine skewness type
    if skewness > 0:
        skew='Right'
    elif skewness < 0:
        skew='Left'
    else:
        skew='No skew'

    plt.subplot(rows, cols, i)  
    sns.histplot(df[col], kde=True, bins=20, color='blue', alpha=0.7)
    
    # Add mean, median, and mode lines
    mode_val = df[col].mode()[0]
    plt.axvline(mean, color='red', linestyle='--', label=f'Mean: {mean:.2f}')
    plt.axvline(median, color='green', linestyle='--', label=f'Median: {median:.2f}')
    plt.axvline(mode_val, color='purple', linestyle='--', label=f'Mode: {mode_val:.2f}')
    
    # Titles and labels
    plt.title(f"Histogram of {col}-{skew}")
    plt.xlabel(col)
    plt.ylabel("Density / Frequency")
    plt.legend()
    plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 6) Boxplot

# %%
# Set the pastel color palette
sns.set_palette("pastel")

# Create a figure with 2 rows and 2 columns for boxplots
plt.figure(figsize=(15, 12))

# Boxplot 2: Comparison of HbA1c Level across Hypertension status
plt.subplot(2, 2, 2)
sns.boxplot(x='hypertension', y='HbA1c_level', data=df, hue='hypertension')
plt.title('Comparison of HbA1c Level Across Hypertension Status')

# Boxplot 3: Comparison of Blood Glucose Level across Heart Disease status
plt.subplot(2, 2, 1)
sns.boxplot(x='heart_disease', y='blood_glucose_level', data=df, hue='heart_disease')
plt.title('Comparison of Blood Glucose Level Across Heart Disease Status')

# Adjust layout and show the plots
plt.tight_layout()
plt.show()

#Interpretation :
    # - Outliers:Dots represent outliers in the boxplot
    # - Median (Central Line): The line inside the box
    # - Interquartile Range (IQR): The distance between the 1st quartile (Q1) and 3rd quartile (Q3), which makes up the box
    # - Whiskers: Lines that extend from the box to the smallest and largest values within 1.5 times the IQR from the lower and upper quartiles.

# %% [markdown]
# <h3>Interpretation : </h3>
# <span style="font-style: italic;font-size: 18px;">
#     Outliers:Dots represent outliers in the boxplot
#     Median (Central Line): The line inside the box
#     Interquartile Range (IQR): The distance between the 1st quartile (Q1) and 3rd quartile (Q3), which makes up the box
#     Whiskers: Lines that extend from the box to the smallest and largest values within 1.5 times the IQR from the lower and upper quartiles.</span>

# %% [markdown]
# # 7) Countplots

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
plt.figure(figsize=(15, 10))
for i, column in enumerate(categorical_columns, 1):
    plt.subplot(3, 3, i) 
    sns.countplot(x=column, data=df, hue='diabetes', palette='pastel')
    plt.title(f"Count Plot of {column} vs Diabetes")
    plt.xlabel(column)
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3 style="font-weight: bold;">Dataset Interpretation:</h3> <span style="font-style: italic;font-size: 18px;"> The dataset cosnists 2 categorical variables. Gender : female number is high comapred to male.</span>

# %% [markdown]
# # 5) Bivariate Analysis - Scatterplots

# %%
# Positive Correlation (e.g., age vs. HbA1c_level)
plt.figure(figsize=(18, 5))

plt.subplot(1, 3, 1)
sns.scatterplot(x='age', y='HbA1c_level', data=df, color='green')
plt.title('Positive Correlation: Age vs HbA1c Level', fontsize=14)
plt.xlabel('Age')
plt.ylabel('HbA1c Level')

# Negative Correlation (e.g., age vs. height)
plt.subplot(1, 3, 2)
sns.scatterplot(x='HbA1c_level', y='blood_glucose_level', data=df, color='red')
plt.title('Negative Correlation: Hba1c Level vs blood_glucose_levelt', fontsize=14)
plt.xlabel('Age')
plt.ylabel('Height')

# No Correlation (e.g., gender vs. BMI as an example if categorical, but can be extended)
plt.subplot(1, 3, 3)
sns.scatterplot(x='bmi', y='blood_glucose_level', data=df, color='blue')
plt.title('No Correlation: BMI vs Blood Glucose Level', fontsize=14)
plt.xlabel('BMI')
plt.ylabel('Blood Glucose Level')

plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Interpretation : </h3>
# <span style="font-style: italic;font-size: 18px;">Positive Correlation: As one variable increases, so does the other (Age and HbA1c).<br>
# Negative Correlation: As one variable increases, the other decreases (Hba1c and blood glucose).<br>
# No Correlation: No clear trend or pattern exists between the two variables (BMI and Blood Glucose Level).</span>

# %% [markdown]
# # 6) Multivariate Analysis - Heatmap

# %%
#Multivariate Analysis
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns
correlation_matrix = df[numerical_columns].corr()

# Correlation heatmap for numerical columns in the dataset
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", vmin=-1, vmax=1)
plt.title("Correlation Heatmap of Numerical Features", fontsize=16)
plt.show()

# %% [markdown]
# <h3>Interpretation : </h3>
# <span style="font-style: italic;font-size: 18px;">The heatmap will display a grid where each cell represents the correlation between two variables.
#     #Positive correlations are highlighted in shades of blue.
#     #Negative correlations are in shades of red.
#     #A correlation of 0 will be neutral (often white or gray)</span>

# %% [markdown]
# # 7) Categorical encoding

# %%
from sklearn.preprocessing import LabelEncoder
df["gender"] = LabelEncoder().fit_transform(df['gender'])
df["smoking_history"] = LabelEncoder().fit_transform(df['smoking_history'])
print(df)
# Out:
#      gender   age  hypertension  heart_disease  smoking_history    bmi  \
# 0         0  80.0           0.0            1.0                4  25.19
# 1         0  54.0           0.0            0.0                0  27.32
# 2         1  28.0           0.0            0.0                4  27.32
# 3         0  36.0           0.0            0.0                1  23.45
# 4         1  76.0           1.0            1.0                1  20.14
# ..      ...   ...           ...            ...              ...    ...
# 695       0  62.0           0.0            0.0                2  27.27
# 696       0  53.0           0.0            0.0                2  42.40
# 697       0  55.0           0.0            0.0                4  35.42
# 698       0  64.0           0.0            0.0                2  49.27
# 699       0  40.0           0.0            0.0                4  31.16
#
#      HbA1c_level  blood_glucose_level  diabetes  height  weight
# 0            6.6                  140         0  171.52   74.11
# 1            6.6                   80         0  176.48   83.74
# 2            5.7                  158         0  163.29   58.46
# 3            5.0                  155         0  187.04   52.77
# 4            4.8                  155         0  154.72   68.39
# ..           ...                  ...       ...     ...     ...
# 695          5.8                  130         0  160.22   64.78
# 696          6.1                  145         0  174.95   58.62
# 697          6.5                  140         0  177.31   67.39
# 698          8.2                  140         1  168.39   80.27
# 699          6.6                  159         1  182.65   79.69
#
# [700 rows x 11 columns]

# %% [markdown]
# <h3 style="font-weight: bold;">Dataset Interpretation:</h3>
#
# <span style="font-style: italic;font-size: 18px;">The categorical features,gender and smoking history, have been numerically encoded for analysis.</span>
# <span style="font-style: italic;font-size: 18px;">Key health indicators like BMI, HbA1c levels, and blood glucose levels play a crucial role in assessing diabetes risk.</span>

# %% [markdown]
# # Neural Networks
#
# <p style="font-style: italic; font-size: 18px;">
#     A Neural Network in machine learning is a computational model inspired by the human brain. It consists of layers of neurons (nodes) that process and transform input data to make predictions or classifications.
# </p>
#
# <p style="font-style: italic; font-size: 18px;">
#     <strong>MLP (Multi-Layer Perceptron)</strong> is a type of artificial neural network (ANN) that consists of multiple layers of neurons.
# </p>
#
# <ul style="font-style: italic; font-size: 18px;">
#     <li><strong>Input Layer</strong> – Receives data (features).</li>
#     <li><strong>Hidden Layers</strong> – Perform computations using weights and activation functions.</li>
#     <li><strong>Output Layer</strong> – Produces the final result (e.g., classification, regression).</li>
# </ul>

# %% [markdown]
# # 8) Split dataset

# %%
from imblearn.over_sampling import SMOTE
from sklearn.neural_network import MLPClassifier

# %%
X=df.drop('diabetes',axis=1).values  #independent variable - features
y=df['diabetes'].values   #dependent variable - target

print("\nDependent Variable (Target):")
print("diabetes")
print("\nIndependent Variables (Features):")
feature_names =print(df.columns.drop('diabetes').tolist())
# Out:
# Dependent Variable (Target):
# diabetes
#
# Independent Variables (Features):
# ['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history', 'bmi', 'HbA1c_level', 'blood_glucose_level', 'height', 'weight']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=21, stratify=y)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)  
X_test = scaler.transform(X_test)

# %% [markdown]
# <h3 style="font-weight: bold;">Dataset Interpretation:</h3>
# <span style="font-style: italic;font-size: 18px;">The independent variables include all columns except 'diabetes', which is the target variable indicating the presence or absence of diabetes.</span>
# <span style="font-style: italic;font-size: 18px;">A train-test split of 60%-40% is used, ensuring a consistent data split with a random state.

# %% [markdown]
# # 9) MLP CLassifier

# %%
clf = MLPClassifier(hidden_layer_sizes=(6,5),
                    random_state=5,
                    verbose=True,
                    learning_rate_init=0.01)
clf.fit(X_train,y_train)
# Out:
# Iteration 1, loss = 0.65248763
# Iteration 2, loss = 0.55299166
# Iteration 3, loss = 0.48266863
# Iteration 4, loss = 0.42749542
# Iteration 5, loss = 0.38354957
# Iteration 6, loss = 0.34875613
# Iteration 7, loss = 0.32158444
# Iteration 8, loss = 0.30068216
# Iteration 9, loss = 0.28495656
# Iteration 10, loss = 0.27401709
# Iteration 11, loss = 0.26398169
# Iteration 12, loss = 0.25296086
# Iteration 13, loss = 0.24463559
# Iteration 14, loss = 0.23724830
# Iteration 15, loss = 0.23078845
# Iteration 16, loss = 0.22614435
# Iteration 17, loss = 0.22162824
# Iteration 18, loss = 0.21755889
# Iteration 19, loss = 0.21395399
# Iteration 20, loss = 0.20978507
# Iteration 21, loss = 0.20605054
# Iteration 22, loss = 0.20216693
# Iteration 23, loss = 0.19890338
# Iteration 24, loss = 0.19618510
# Iteration 25, loss = 0.19304993
# Iteration 26, loss = 0.19013702
# Iteration 27, loss = 0.18774474
# Iteration 28, loss = 0.18496776
# Iteration 29, loss = 0.18223601
# Iteration 30, loss = 0.17947170
# Iteration 31, loss = 0.17673877
# Iteration 32, loss = 0.17434165
# Iteration 33, loss = 0.17151873
# Iteration 34, loss = 0.16899599
# Iteration 35, loss = 0.16639249
# Iteration 36, loss = 0.16348945
# Iteration 37, loss = 0.16093998
# Iteration 38, loss = 0.15840111
# Iteration 39, loss = 0.15593836
# Iteration 40, loss = 0.15286145
# Iteration 41, loss = 0.15114275
# Iteration 42, loss = 0.15021147
# Iteration 43, loss = 0.14913363
# Iteration 44, loss = 0.14659383
# Iteration 45, loss = 0.14399057
# Iteration 46, loss = 0.14127002
# Iteration 47, loss = 0.13796339
# Iteration 48, loss = 0.13713412
# Iteration 49, loss = 0.13563840
# Iteration 50, loss = 0.13371741
# Iteration 51, loss = 0.13154691
# Iteration 52, loss = 0.12916642
# Iteration 53, loss = 0.12701349
# Iteration 54, loss = 0.12502474
# Iteration 55, loss = 0.12316194
# Iteration 56, loss = 0.12080957
# Iteration 57, loss = 0.11916866
# Iteration 58, loss = 0.11740058
# Iteration 59, loss = 0.11530826
# Iteration 60, loss = 0.11410556
# Iteration 61, loss = 0.11264786
# Iteration 62, loss = 0.11114497
# Iteration 63, loss = 0.11174077
# Iteration 64, loss = 0.11076289
# Iteration 65, loss = 0.10900278
# Iteration 66, loss = 0.10729269
# Iteration 67, loss = 0.10774691
# Iteration 68, loss = 0.10997575
# Iteration 69, loss = 0.10982440
# Iteration 70, loss = 0.10766140
# Iteration 71, loss = 0.10483203
# Iteration 72, loss = 0.10305784
# Iteration 73, loss = 0.10237815
# Iteration 74, loss = 0.10424714
# Iteration 75, loss = 0.10560276
# Iteration 76, loss = 0.10628347
# Iteration 77, loss = 0.10400981
# Iteration 78, loss = 0.10057421
# Iteration 79, loss = 0.09892198
# Iteration 80, loss = 0.09940171
# Iteration 81, loss = 0.09872230
# Iteration 82, loss = 0.09753022
# Iteration 83, loss = 0.09624853
# Iteration 84, loss = 0.09446146
# Iteration 85, loss = 0.09585061
# Iteration 86, loss = 0.09658587
# Iteration 87, loss = 0.09759462
# Iteration 88, loss = 0.09674764
# Iteration 89, loss = 0.09503331
# Iteration 90, loss = 0.09381445
# Iteration 91, loss = 0.09311700
# Iteration 92, loss = 0.09222682
# Iteration 93, loss = 0.09101521
# Iteration 94, loss = 0.08903259
# Iteration 95, loss = 0.08823115
# Iteration 96, loss = 0.08744372
# Iteration 97, loss = 0.08653202
# Iteration 98, loss = 0.08587435
# Iteration 99, loss = 0.08538488
# Iteration 100, loss = 0.08499438
# Iteration 101, loss = 0.08480796
# Iteration 102, loss = 0.08404299
# Iteration 103, loss = 0.08274447
# Iteration 104, loss = 0.08200668
# Iteration 105, loss = 0.08126071
# Iteration 106, loss = 0.08096567
# Iteration 107, loss = 0.08191086
# Iteration 108, loss = 0.08160897
# Iteration 109, loss = 0.08151703
# Iteration 110, loss = 0.08079567
# Iteration 111, loss = 0.07853009
# Iteration 112, loss = 0.07778360
# Iteration 113, loss = 0.07724074
# Iteration 114, loss = 0.07717942
# Iteration 115, loss = 0.07643556
# Iteration 116, loss = 0.07770678
# Iteration 117, loss = 0.07723205
# Iteration 118, loss = 0.07822097
# Iteration 119, loss = 0.07684598
# Iteration 120, loss = 0.07510690
# Iteration 121, loss = 0.07439630
# Iteration 122, loss = 0.07395945
# Iteration 123, loss = 0.07384215
# Iteration 124, loss = 0.07350445
# Iteration 125, loss = 0.07327541
# Iteration 126, loss = 0.07275689
# Iteration 127, loss = 0.07224796
# Iteration 128, loss = 0.07193338
# Iteration 129, loss = 0.07390716
# Iteration 130, loss = 0.07501060
# Iteration 131, loss = 0.07440470
# Iteration 132, loss = 0.07429141
# Iteration 133, loss = 0.07452143
# Iteration 134, loss = 0.07405009
# Iteration 135, loss = 0.07340607
# Iteration 136, loss = 0.07280030
# Iteration 137, loss = 0.07232225
# Iteration 138, loss = 0.07154527
# Iteration 139, loss = 0.07169665
# Iteration 140, loss = 0.07127926
# Iteration 141, loss = 0.07156139
# Iteration 142, loss = 0.07768481
# Iteration 143, loss = 0.07646294
# Iteration 144, loss = 0.07480918
# Iteration 145, loss = 0.07222579
# Iteration 146, loss = 0.07322034
# Iteration 147, loss = 0.07501962
# Iteration 148, loss = 0.07469814
# Iteration 149, loss = 0.07212810
# Iteration 150, loss = 0.07008734
# Iteration 151, loss = 0.06949392
# Iteration 152, loss = 0.06911954
# Iteration 153, loss = 0.06933699
# Iteration 154, loss = 0.06931087
# Iteration 155, loss = 0.06924063
# Iteration 156, loss = 0.06765587
# Iteration 157, loss = 0.06764001
# Iteration 158, loss = 0.06864112
# Iteration 159, loss = 0.06601291
# Iteration 160, loss = 0.06553778
# Iteration 161, loss = 0.06682455
# Iteration 162, loss = 0.06593418
# Iteration 163, loss = 0.06525075
# Iteration 164, loss = 0.06496677
# Iteration 165, loss = 0.06485384
# Iteration 166, loss = 0.06635598
# Iteration 167, loss = 0.06688068
# Iteration 168, loss = 0.06447660
# Iteration 169, loss = 0.06235470
# Iteration 170, loss = 0.06213746
# Iteration 171, loss = 0.06331851
# Iteration 172, loss = 0.06183166
# Iteration 173, loss = 0.05948501
# Iteration 174, loss = 0.05906196
# Iteration 175, loss = 0.06006633
# Iteration 176, loss = 0.06061934
# Iteration 177, loss = 0.05995865
# Iteration 178, loss = 0.05875022
# Iteration 179, loss = 0.05789153
# Iteration 180, loss = 0.05725072
# Iteration 181, loss = 0.05677022
# Iteration 182, loss = 0.05647687
# Iteration 183, loss = 0.05971996
# Iteration 184, loss = 0.06132176
# Iteration 185, loss = 0.05693257
# Iteration 186, loss = 0.05706703
# Iteration 187, loss = 0.06332733
# Iteration 188, loss = 0.06553928
# Iteration 189, loss = 0.06311237
# Iteration 190, loss = 0.05982511
# Iteration 191, loss = 0.05936173
# Iteration 192, loss = 0.06070228
# Iteration 193, loss = 0.06070562
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# MLPClassifier(hidden_layer_sizes=(6, 5), learning_rate_init=0.01,
#               random_state=5, verbose=True)

# %% [markdown]
# <h3 style="font-weight: bold;">Dataset Interpretation:</h3>
#
# <ul style="font-style: italic;font-size: 18px;">
#     <li>A Multi-Layer Perceptron (MLP) classifier is used for training, consisting of two hidden layers with 6 and 5 neurons respectively.</li>
#     <li>TSets the initial learning rate to 0.01, which controls how much weights are updated in each step.</li>
#     <li>Verbose mode is enabled, displaying the loss at each iteration, which shows the model's progress in minimizing the error during training.</li>
#     <li>Each iteration represents one update step during training.Loss decreases as the model learns.Lower loss means better performance.</li>
# </ul>

# %%
# Making prediction
y_pred = clf.predict(X_test)
cm=confusion_matrix(y_pred,y_test)

plt.figure(figsize=(6,5))
sns.heatmap(cm,annot=True,fmt='d',cmap='Greens')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# <h3 style="font-weight: bold;">Dataset Interpretation:</h3>
#
# <ul style="font-style: italic;font-size: 18px;">
#     <li>The confusion matrix output is:
#         <ul>
#             <li>True Positives (TP): 11 (Correctly predicted positive cases)</li>
#             <li>False Positives (FP): 15 (Incorrectly predicted positive cases)</li>
#             <li>False Negatives (FN): 6 (Incorrectly predicted negative cases)</li>
#             <li>True Negatives (TN): 248 (Correctly predicted negative cases)</li>
#         </ul>
#     </li>
# </ul>

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.98      0.96       254
#            1       0.65      0.42      0.51        26
#
#     accuracy                           0.93       280
#    macro avg       0.80      0.70      0.74       280
# weighted avg       0.92      0.93      0.92       280

# %% [markdown]
# <h3 style="font-weight: bold;">Dataset Interpretation:</h3>
#
# <ul style="font-style: italic;font-size: 18px;">
#     <li><strong>Accuracy:</strong> The percentage of correctly predicted instances out of the total instances.</li>
#     <li><strong>Precision:</strong> The proportion of correctly predicted positive cases out of all predicted positive cases.</li>
#     <li><strong>Recall:</strong> The proportion of correctly predicted positive cases out of all actual positive cases.</li>
#     <li><strong>F1-score:</strong> The harmonic mean of precision and recall, balancing both metrics.</li>
# </ul>

# %%
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.4f}')
# Out:
# Accuracy: 0.9250

# %% [markdown]
# <h3 style="font-weight: bold;">Dataset Interpretation:</h3>
# <ul style="font-style: italic;font-size: 18px;">
#     <li>Accuracy (92.50%): The model correctly predicts 92.50% of the total instances.</li>
#     <li>Accuracy measures the overall correctness of the model’s predictions.</li>
# </ul>

# %%
# Plot loss curve
plt.plot(clf.loss_curve_)
plt.xlabel('Iterations')
plt.ylabel('Loss')
plt.title('MLP Loss Curve')
plt.show()

# %% [markdown]
# <h3 style="font-weight: bold;">Dataset Interpretation:</h3>
#
# <ul style="font-style: italic;font-size: 18px;">
#     <li>Loss Curve:The plot shows how the model's loss decreases over iterations.</li>
#     <li>Loss represents the error between the predicted and actual values.</li>
#     <li>A decreasing loss curve indicates that the model is learning and improving over time.</li>
# </ul>

# %%
y_prob = clf.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_prob)
plt.plot(fpr, tpr, label=f'AUC = {auc(fpr, tpr):.2f}')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %% [markdown]
# <h3 style="font-weight: bold;">Dataset Interpretation:</h3>
# <ul style="font-style: italic;font-size: 18px;">
#     <li><strong>ROC Curve:</strong> The ROC (Receiver Operating Characteristic) curve is a plot that shows the trade-off between TPR and  (FPR) at different thresholds.</li>
#     <li><strong>AUC (0.82):</strong> The Area Under the Curve (AUC) measures the model's ability to classify positive and negative cases.81% chance of ranking a positive instance higher than a negative one</li>
#     <li>AUC values range from 0 to 1:
#         <ul>
#             <li>0.5 indicates random guessing.</li>
#             <li>Above 0.8 suggests good model performance.</li>
#         </ul>
#     </li>
# </ul>

# %%
feature_names = df.columns.drop('diabetes').tolist()
print(feature_names)

# Feature importance analysis (Ensure clf is trained)
feature_importance = np.abs(clf.coefs_[0]).mean(axis=1)

# Plot feature importance
plt.figure(figsize=(12, 6))
plt.bar(feature_names, feature_importance)
plt.xticks(rotation=45, ha='right')
plt.title('Feature Importance')
plt.xlabel('Features')
plt.ylabel('Importance Score')
plt.tight_layout()
plt.show()
# Out:
# ['gender', 'age', 'hypertension', 'heart_disease', 'smoking_history', 'bmi', 'HbA1c_level', 'blood_glucose_level', 'height', 'weight']

# %% [markdown]
# <h3 style="font-weight: bold;">Dataset Interpretation:</h3>
# <span style="font-style: italic;font-size: 18px;">clf.coefs_[0] → Extracts the weights between the input layer and the first hidden layer.
# np.abs(clf.coefs_[0]) → Takes the absolute values of the weights.
# .mean(axis=1) → Computes the average importance of each feature across all neurons in the first hidden layer.
# Higher values indicate more important features.</span>

# %%
# Print model performance metrics
print("\nModel Performance Metrics:")
print(f"Training set score: {clf.score(X_train, y_train):.3f}")
print(f"Test set score: {clf.score(X_test, y_test):.3f}")
print(f"Number of iterations: {getattr(clf, 'n_iter_', 'N/A')}")
print(f"Number of layers: {len(clf.coefs_)}")
print("Layer sizes:", [layer.shape for layer in clf.coefs_])
# Out:
# Model Performance Metrics:
# Training set score: 0.983
# Test set score: 0.925
# Number of iterations: 193
# Number of layers: 3
# Layer sizes: [(10, 6), (6, 5), (5, 1)]

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'hidden_layer_sizes': [(10,10), (20,20), (30,30)],
    'activation': ['relu', 'tanh'],
    'alpha': [0.0001, 0.001, 0.01],
    'learning_rate_init': [0.001, 0.01]
}

grid_search = GridSearchCV(MLPClassifier(max_iter=50, random_state=42), param_grid, cv=5)
grid_search.fit(X_train, y_train)
print(grid_search.best_params_)
# Out:
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate_init': 0.01}
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# <h3 style="font-weight: bold;">Dataset Interpretation:</h3>
#
# <ul style="font-style: italic;font-size: 18px;">
#     <li><strong>Grid Search:</strong> A technique to find the optimal hyperparameters for the model.</li>
#     <li>Best Parameters Found:</li>
#     <ul>
#         <li>>Activation Function: ReLU - Helps the model learn complex patterns efficiently.</li>
#         <li>Hidden Layer Sizes: (30,30)- Two hidden layers, each with 30 neurons, improving learning capacity.</li>
#         <li>Alpha: 0.0001 - A regularization parameter that prevents overfitting.</li>
#         <li>Learning Rate Init: 0.01 - Defines the step size for weight updates, balancing speed and stability.</li>
#     </ul>
# </ul>

# %% [markdown]
# # 9) New Optimal Parameters

# %%
# Train the final model with best parameters
clf_best = MLPClassifier(
    activation='tanh',
    alpha=0.0001,
    hidden_layer_sizes=(20, 20),
    learning_rate_init=0.01,
    max_iter=300,  # Increase iterations to ensure better convergence
    random_state=42,
    verbose=True  # To see training progress
)

clf_best.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 0.65381204
# Iteration 2, loss = 0.43936234
# Iteration 3, loss = 0.32506051
# Iteration 4, loss = 0.26248567
# Iteration 5, loss = 0.22197327
# Iteration 6, loss = 0.19556833
# Iteration 7, loss = 0.17302330
# Iteration 8, loss = 0.15743481
# Iteration 9, loss = 0.14767055
# Iteration 10, loss = 0.14319948
# Iteration 11, loss = 0.13681840
# Iteration 12, loss = 0.12705697
# Iteration 13, loss = 0.12495636
# Iteration 14, loss = 0.12291613
# Iteration 15, loss = 0.12087969
# Iteration 16, loss = 0.11916189
# Iteration 17, loss = 0.11675725
# Iteration 18, loss = 0.11347293
# Iteration 19, loss = 0.11156535
# Iteration 20, loss = 0.10847948
# Iteration 21, loss = 0.10849757
# Iteration 22, loss = 0.11279813
# Iteration 23, loss = 0.11436190
# Iteration 24, loss = 0.10916315
# Iteration 25, loss = 0.10572784
# Iteration 26, loss = 0.10499154
# Iteration 27, loss = 0.10418940
# Iteration 28, loss = 0.10325054
# Iteration 29, loss = 0.10354065
# Iteration 30, loss = 0.10534932
# Iteration 31, loss = 0.10824488
# Iteration 32, loss = 0.10331092
# Iteration 33, loss = 0.09875766
# Iteration 34, loss = 0.09625086
# Iteration 35, loss = 0.09807230
# Iteration 36, loss = 0.10191062
# Iteration 37, loss = 0.10334596
# Iteration 38, loss = 0.10069177
# Iteration 39, loss = 0.09641423
# Iteration 40, loss = 0.09284508
# Iteration 41, loss = 0.09138110
# Iteration 42, loss = 0.09086029
# Iteration 43, loss = 0.09253788
# Iteration 44, loss = 0.09076512
# Iteration 45, loss = 0.08699907
# Iteration 46, loss = 0.08701953
# Iteration 47, loss = 0.09000463
# Iteration 48, loss = 0.08917997
# Iteration 49, loss = 0.08774413
# Iteration 50, loss = 0.08752899
# Iteration 51, loss = 0.08788146
# Iteration 52, loss = 0.08521168
# Iteration 53, loss = 0.08254813
# Iteration 54, loss = 0.08036624
# Iteration 55, loss = 0.08101013
# Iteration 56, loss = 0.07963259
# Iteration 57, loss = 0.08054797
# Iteration 58, loss = 0.08496093
# Iteration 59, loss = 0.08463844
# Iteration 60, loss = 0.07930954
# Iteration 61, loss = 0.07712964
# Iteration 62, loss = 0.07858156
# Iteration 63, loss = 0.07865400
# Iteration 64, loss = 0.07747652
# Iteration 65, loss = 0.07512372
# Iteration 66, loss = 0.07243595
# Iteration 67, loss = 0.07180594
# Iteration 68, loss = 0.07395326
# Iteration 69, loss = 0.07291423
# Iteration 70, loss = 0.07404309
# Iteration 71, loss = 0.07214918
# Iteration 72, loss = 0.07390062
# Iteration 73, loss = 0.07511788
# Iteration 74, loss = 0.06963692
# Iteration 75, loss = 0.06676289
# Iteration 76, loss = 0.06813556
# Iteration 77, loss = 0.07153366
# Iteration 78, loss = 0.07632293
# Iteration 79, loss = 0.07563961
# Iteration 80, loss = 0.06902212
# Iteration 81, loss = 0.06356494
# Iteration 82, loss = 0.06567551
# Iteration 83, loss = 0.06705212
# Iteration 84, loss = 0.06351361
# Iteration 85, loss = 0.06832573
# Iteration 86, loss = 0.06924860
# Iteration 87, loss = 0.06486725
# Iteration 88, loss = 0.06147257
# Iteration 89, loss = 0.06013715
# Iteration 90, loss = 0.05865856
# Iteration 91, loss = 0.05845746
# Iteration 92, loss = 0.06027095
# Iteration 93, loss = 0.05980100
# Iteration 94, loss = 0.05708750
# Iteration 95, loss = 0.05582487
# Iteration 96, loss = 0.05654176
# Iteration 97, loss = 0.05765028
# Iteration 98, loss = 0.05726749
# Iteration 99, loss = 0.05583754
# Iteration 100, loss = 0.05659127
# Iteration 101, loss = 0.05904303
# Iteration 102, loss = 0.05420507
# Iteration 103, loss = 0.05310838
# Iteration 104, loss = 0.05643205
# Iteration 105, loss = 0.05568903
# Iteration 106, loss = 0.05291230
# Iteration 107, loss = 0.05138682
# Iteration 108, loss = 0.05041761
# Iteration 109, loss = 0.05062586
# Iteration 110, loss = 0.04977341
# Iteration 111, loss = 0.04797468
# Iteration 112, loss = 0.04966378
# Iteration 113, loss = 0.05377623
# Iteration 114, loss = 0.05822814
# Iteration 115, loss = 0.05408764
# Iteration 116, loss = 0.04861646
# Iteration 117, loss = 0.04793082
# Iteration 118, loss = 0.05154316
# Iteration 119, loss = 0.05011846
# Iteration 120, loss = 0.04637179
# Iteration 121, loss = 0.04425668
# Iteration 122, loss = 0.04368288
# Iteration 123, loss = 0.04297154
# Iteration 124, loss = 0.04225332
# Iteration 125, loss = 0.04139430
# Iteration 126, loss = 0.04099976
# Iteration 127, loss = 0.04068737
# Iteration 128, loss = 0.04039959
# Iteration 129, loss = 0.03956929
# Iteration 130, loss = 0.03911226
# Iteration 131, loss = 0.03883779
# Iteration 132, loss = 0.03860517
# Iteration 133, loss = 0.03871995
# Iteration 134, loss = 0.03881393
# Iteration 135, loss = 0.03833923
# Iteration 136, loss = 0.03781976
# Iteration 137, loss = 0.03798173
# Iteration 138, loss = 0.03747522
# Iteration 139, loss = 0.03703244
# Iteration 140, loss = 0.03636620
# Iteration 141, loss = 0.03645577
# Iteration 142, loss = 0.03708959
# Iteration 143, loss = 0.03671580
# Iteration 144, loss = 0.03527639
# Iteration 145, loss = 0.03375755
# Iteration 146, loss = 0.03710829
# Iteration 147, loss = 0.03792387
# Iteration 148, loss = 0.03495561
# Iteration 149, loss = 0.03360870
# Iteration 150, loss = 0.03285609
# Iteration 151, loss = 0.03342144
# Iteration 152, loss = 0.03226002
# Iteration 153, loss = 0.03613558
# Iteration 154, loss = 0.04143024
# Iteration 155, loss = 0.03860587
# Iteration 156, loss = 0.03258116
# Iteration 157, loss = 0.03121662
# Iteration 158, loss = 0.03253936
# Iteration 159, loss = 0.03316409
# Iteration 160, loss = 0.03102091
# Iteration 161, loss = 0.02996351
# Iteration 162, loss = 0.02989343
# Iteration 163, loss = 0.02981841
# Iteration 164, loss = 0.02938223
# Iteration 165, loss = 0.02886435
# Iteration 166, loss = 0.02812270
# Iteration 167, loss = 0.02761082
# Iteration 168, loss = 0.02763569
# Iteration 169, loss = 0.02742711
# Iteration 170, loss = 0.02714116
# Iteration 171, loss = 0.02709439
# Iteration 172, loss = 0.02770576
# Iteration 173, loss = 0.02839787
# Iteration 174, loss = 0.02818382
# Iteration 175, loss = 0.02756634
# Iteration 176, loss = 0.02643544
# Iteration 177, loss = 0.02504771
# Iteration 178, loss = 0.02448015
# Iteration 179, loss = 0.02470673
# Iteration 180, loss = 0.02446963
# Iteration 181, loss = 0.02363193
# Iteration 182, loss = 0.02314064
# Iteration 183, loss = 0.02283422
# Iteration 184, loss = 0.02283386
# Iteration 185, loss = 0.02277349
# Iteration 186, loss = 0.02250848
# Iteration 187, loss = 0.02292570
# Iteration 188, loss = 0.02227809
# Iteration 189, loss = 0.02196065
# Iteration 190, loss = 0.02133214
# Iteration 191, loss = 0.02091530
# Iteration 192, loss = 0.02217271
# Iteration 193, loss = 0.02381942
# Iteration 194, loss = 0.02548270
# Iteration 195, loss = 0.02669179
# Iteration 196, loss = 0.02487227
# Iteration 197, loss = 0.02242127
# Iteration 198, loss = 0.02030021
# Iteration 199, loss = 0.02107918
# Iteration 200, loss = 0.03146377
# Iteration 201, loss = 0.02327488
# Iteration 202, loss = 0.02456780
# Iteration 203, loss = 0.03118692
# Iteration 204, loss = 0.02529389
# Iteration 205, loss = 0.02049237
# Iteration 206, loss = 0.02337753
# Iteration 207, loss = 0.02076110
# Iteration 208, loss = 0.01970854
# Iteration 209, loss = 0.01953895
# Iteration 210, loss = 0.01954338
# Iteration 211, loss = 0.02097637
# Iteration 212, loss = 0.02099893
# Iteration 213, loss = 0.01963353
# Iteration 214, loss = 0.01758478
# Iteration 215, loss = 0.01556238
# Iteration 216, loss = 0.01501489
# Iteration 217, loss = 0.01659884
# Iteration 218, loss = 0.01817772
# Iteration 219, loss = 0.01700311
# Iteration 220, loss = 0.01686765
# Iteration 221, loss = 0.01638284
# Iteration 222, loss = 0.01468564
# Iteration 223, loss = 0.01267654
# Iteration 224, loss = 0.01255811
# Iteration 225, loss = 0.01257639
# Iteration 226, loss = 0.01213439
# Iteration 227, loss = 0.01184750
# Iteration 228, loss = 0.01157779
# Iteration 229, loss = 0.01165738
# Iteration 230, loss = 0.01212655
# Iteration 231, loss = 0.01215485
# Iteration 232, loss = 0.01185027
# Iteration 233, loss = 0.01116569
# Iteration 234, loss = 0.01080137
# Iteration 235, loss = 0.01041570
# Iteration 236, loss = 0.01203898
# Iteration 237, loss = 0.01244584
# Iteration 238, loss = 0.01065673
# Iteration 239, loss = 0.00967923
# Iteration 240, loss = 0.00904979
# Iteration 241, loss = 0.00914335
# Iteration 242, loss = 0.00986964
# Iteration 243, loss = 0.00962366
# Iteration 244, loss = 0.00894127
# Iteration 245, loss = 0.00904600
# Iteration 246, loss = 0.01032610
# Iteration 247, loss = 0.00982203
# Iteration 248, loss = 0.00851526
# Iteration 249, loss = 0.00952757
# Iteration 250, loss = 0.00952359
# Iteration 251, loss = 0.00857250
# Iteration 252, loss = 0.00774719
# Iteration 253, loss = 0.00755585
# Iteration 254, loss = 0.00823129
# Iteration 255, loss = 0.00909373
# Iteration 256, loss = 0.00776490
# Iteration 257, loss = 0.00719294
# Iteration 258, loss = 0.00676669
# Iteration 259, loss = 0.00760998
# Iteration 260, loss = 0.00779928
# Iteration 261, loss = 0.00711258
# Iteration 262, loss = 0.00604867
# Iteration 263, loss = 0.00601741
# Iteration 264, loss = 0.00641476
# Iteration 265, loss = 0.00661329
# Iteration 266, loss = 0.00634640
# Iteration 267, loss = 0.00577927
# Iteration 268, loss = 0.00546695
# Iteration 269, loss = 0.00657440
# Iteration 270, loss = 0.00663474
# Iteration 271, loss = 0.00588896
# Iteration 272, loss = 0.00521600
# Iteration 273, loss = 0.00500386
# Iteration 274, loss = 0.00485502
# Iteration 275, loss = 0.00462209
# Iteration 276, loss = 0.00446743
# Iteration 277, loss = 0.00439119
# Iteration 278, loss = 0.00433694
# Iteration 279, loss = 0.00429399
# Iteration 280, loss = 0.00429770
# Iteration 281, loss = 0.00422621
# Iteration 282, loss = 0.00417280
# Iteration 283, loss = 0.00409435
# Iteration 284, loss = 0.00402745
# Iteration 285, loss = 0.00392049
# Iteration 286, loss = 0.00384833
# Iteration 287, loss = 0.00382192
# Iteration 288, loss = 0.00377695
# Iteration 289, loss = 0.00406914
# Iteration 290, loss = 0.00423068
# Iteration 291, loss = 0.00427404
# Iteration 292, loss = 0.00414258
# Iteration 293, loss = 0.00379265
# Iteration 294, loss = 0.00360358
# Iteration 295, loss = 0.00341369
# Iteration 296, loss = 0.00338179
# Iteration 297, loss = 0.00340752
# Iteration 298, loss = 0.00337621
# Iteration 299, loss = 0.00333555
# Iteration 300, loss = 0.00326333
# C:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(activation='tanh', hidden_layer_sizes=(20, 20),
#               learning_rate_init=0.01, max_iter=300, random_state=42,
#               verbose=True)

# %% [markdown]
# <h3 style="font-weight: bold;">Dataset Interpretation:</h3>
# <ul style="font-style: italic;font-size: 18px;">
#     <li>Final MLP Model Training: The model is trained with the best hyperparameters found using Grid Search.</li>
#     <li>Hyperparameters Used:</li>
#     <ul>
#         <li>Hidden Layer Sizes: (30,30) - Two hidden layers with 30 neurons each for better learning.</li>
#         <li>Activation Function: ReLU - Helps the model learn non-linear patterns efficiently.</li>
#         <li>Alpha: 0.0001 - A regularization term to prevent overfitting.</li>
#         <li>Learning Rate Init: 0.001 - Controls the speed of weight updates.</li>
#         <li>Max Iterations: 200 - The model trains for up to 200 iterations.</li>
#         <li>Random State: 42 - Ensures reproducibility of results.</li>
#     </ul>
# </ul>

# %%
y_predd = clf_best.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_predd))
print("Classification Report:\n", classification_report(y_test, y_predd))
# Out:
# Accuracy: 0.9321428571428572
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96       254
#            1       0.65      0.58      0.61        26
#
#     accuracy                           0.93       280
#    macro avg       0.80      0.77      0.79       280
# weighted avg       0.93      0.93      0.93       280

# %% [markdown]
# <h3 style="font-weight: bold;">Model Evaluation:</h3>
# <ul style="font-style: italic;font-size: 18px;">
#     <li>Accuracy: 94% - The model correctly classifies 94% of test samples.</li>
#     <li>Class 0 (Non-Diabetic) Performance:</li>
#     <ul>
#         <li>Precision: 96% - High accuracy in predicting non-diabetic cases.</li>
#         <li>Recall: 93% - Captures most non-diabetic cases correctly.</li>
#         <li>F1-score: 94% - Good balance between precision and recall.</li>
#     </ul>
#     <li>Class 1 (Diabetic) Performance:</li>
#     <ul>
#         <li>Precision: 45% - Lower accuracy in predicting diabetic cases.</li>
#         <li>Recall: 58% - The model detects 58% of actual diabetic cases.</li>
#         <li>F1-score: 51% - Moderate balance between precision and recall.</li>
#     </ul>
# </ul>
